# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload -p 2

import melanoma as mel
import os
import pathlib

snapshot_path = os.path.join(pathlib.Path.cwd(), 'snapshot')
mel.Model.reject_uncertainties(snapshot_path=snapshot_path)
# mel.Model.extract_reject_performances(snapshot_path=snapshot_path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Rejecting /homes/e35889/sansa/melanoma_detection/snapshot/ResNet152/performance/ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics.json model
# Rejecting ISIC2017 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
# Rejecting ISIC2018 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
# Rejecting KaggleMB database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
# Rejecting _7_point_criteria database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
# Rejecting ISIC2017 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               515          17
# Incorrect              55          13
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9035                    0.8800               5.9827
# Rejecting ISIC2018 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct              1253          98
# Incorrect              78          83
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9414                    0.8836               7.1069
# Rejecting KaggleMB database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               510          37
# Incorrect              91          22
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8486                    0.8061               2.8783
# Rejecting _7_point_criteria database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               283          48
# Incorrect              33          31
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8956                    0.7949               3.3402
# Rejecting /homes/e35889/sansa/melanoma_detection/snapshot/ResNet152/performance/ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics.json model
# Rejecting ISIC2017 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting ISIC2018 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting KaggleMB database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting _7_point_criteria database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting ISIC2017 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               454          81
# Incorrect              26          39
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9458                    0.8217               3.9630
# Rejecting ISIC2018 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct              1297          52
# Incorrect             110          53
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9218                    0.8929               8.4352
# Rejecting KaggleMB database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               482          62
# Incorrect              73          43
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8685                    0.7955               3.2525
# Rejecting _7_point_criteria database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               308          19
# Incorrect              44          24
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8750                    0.8405               6.0743
# Rejecting /homes/e35889/sansa/melanoma_detection/snapshot/ResNet152/performance/ISIC2019_ResNet152_metrics.json model
# Rejecting ISIC2017 database from ISIC2019_ResNet152_metrics
# Rejecting ISIC2018 database from ISIC2019_ResNet152_metrics
# Rejecting KaggleMB database from ISIC2019_ResNet152_metrics
# Rejecting _7_point_criteria database from ISIC2019_ResNet152_metrics
# Rejecting ISIC2017 database from ISIC2019_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               464          39
# Incorrect              76          21
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8593                    0.8083               2.7922
# Rejecting ISIC2018 database from ISIC2019_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct              1212         148
# Incorrect              74          78
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9425                    0.8532               4.7155
# Rejecting KaggleMB database from ISIC2019_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               446          51
# Incorrect             122          41
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.7852                    0.7379               2.4512
# Rejecting _7_point_criteria database from ISIC2019_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               277          39
# Incorrect              43          36
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8656                    0.7924               3.6923
# Rejecting /homes/e35889/sansa/melanoma_detection/snapshot/ResNet152/performance/ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics.json model
# Rejecting ISIC2017 database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting ISIC2018 database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting KaggleMB database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting _7_point_criteria database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
# Rejecting ISIC2017 database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               501          26
# Incorrect              51          22
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9076                    0.8717               6.1085
# Rejecting ISIC2018 database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct              1159         202
# Incorrect              51         100
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9579                    0.8327               4.4620
# Rejecting KaggleMB database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               471          85
# Incorrect              57          47
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8920                    0.7848               2.9561
# Rejecting _7_point_criteria database from ISIC2016+ISIC2018+ISIC2019+ISIC2020_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               308          19
# Incorrect              48          20
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8652                    0.8304               5.0619
# Rejecting /homes/e35889/sansa/melanoma_detection/snapshot/ResNet152/performance/ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics.json model
# Rejecting ISIC2017 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
# Rejecting ISIC2018 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
# Rejecting KaggleMB database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
# Rejecting _7_point_criteria database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
# Rejecting ISIC2017 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               456          83
# Incorrect              24          37
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9500                    0.8217               3.9390
# Rejecting ISIC2018 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct              1161         212
# Incorrect              49          90
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9595                    0.8274               4.1934
# Rejecting KaggleMB database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               517          94
# Incorrect              11          38
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.9792                    0.8409               5.0408
# Rejecting _7_point_criteria database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+MEDNODE+KaggleMB_ResNet152_metrics
#              Non-rejected    Rejected
# ---------  --------------  ----------
# Correct               314           9
# Incorrect              58          14
#
#   Non-rejected accuracy    Classification quality    Rejection quality
# -----------------------  ------------------------  -------------------
#                  0.8441                    0.8304               6.9784
