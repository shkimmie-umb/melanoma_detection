# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload -p 2

import melanoma as mel
import os
import pathlib

snapshot_path = os.path.join(pathlib.Path.cwd(), 'snapshot')
# snapshot_path = os.path.join('/raid/mpsych/MELANOMA', 'snapshot')
mel.Model.reject_uncertainties(snapshot_path=snapshot_path)
# mel.Model.extract_reject_performances(snapshot_path=snapshot_path)
# Out:
# Reloading 'melanoma.model'.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Rejecting /home/sanghyuk.kim001/MELANOMA/melanoma-detection-CNN/snapshot/EfficientNetB1/performance/ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2+_7_point_criteria+PAD_UFES_20+MEDNODE+KaggleMB_EfficientNetB1_metrics.json model
# Rejecting ISIC2017 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2+_7_point_criteria+PAD_UFES_20+MEDNODE+KaggleMB_EfficientNetB1_metrics
# Rejecting ISIC2018 database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2+_7_point_criteria+PAD_UFES_20+MEDNODE+KaggleMB_EfficientNetB1_metrics
# Rejecting KaggleMB database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2+_7_point_criteria+PAD_UFES_20+MEDNODE+KaggleMB_EfficientNetB1_metrics
# Rejecting _7_point_criteria database from ISIC2016+ISIC2017+ISIC2018+ISIC2019+ISIC2020+PH2+_7_point_criteria+PAD_UFES_20+MEDNODE+KaggleMB_EfficientNetB1_metrics
# ...
